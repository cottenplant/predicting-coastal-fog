# %%
# Import data science visualization libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Set static vars and pathways
dir_data = r"data/"
file_noaa = "NOAA_LAX_Data.csv"
file_noaa_clean = "NOAA_LAX_Data_Clean.csv"

# %%
# Read data into pandas dataframe
df_noaa = pd.read_csv(dir_data + file_noaa)

# %%
def impute_null_precipitation(col):
        if col == 99.99:
            return 0.0
        else:
            return col

# %%
# Clean data, impute null values where possible and drop unused features
df_lax = df_noaa.loc[df_noaa['STN---'] == 722950]
df_lax.reset_index(inplace=True)
df_lax.columns = df_lax.columns.str.strip()
df_lax.drop(['Unnamed: 0', 'index', 'STN---', 'WBAN', '', '.1', '.2', '.3', '.4', '.5', 'Unnamed: 22', 'SNDP'], axis=1, inplace=True)
df_lax['YEARMODA'] = pd.to_datetime(df_lax['YEARMODA'], format='%Y%m%d')
df_lax['month'] = df_lax['YEARMODA'].apply(lambda date: date.month)
df_lax['year'] = df_lax['YEARMODA'].apply(lambda date: date.year)
df_lax['MAX'] = df_lax['MAX'].apply(lambda col: float(col.strip('*')))
df_lax['MIN'] = df_lax['MIN'].apply(lambda col: float(col.strip('*')))
df_lax['PRCP'] = df_lax['PRCP'].apply(lambda col: float(col[:-1].strip()))
df_lax['PRCP'] = df_lax['PRCP'].apply(impute_null_precipitation)
df_lax['d'] = 1

# %%
df_lax['FRSHTT'].value_counts()
# Out:
# 0         10009
# 100000     4251
# 10000      1169
# 110000      958
# 10010       106
# 110010       61
# 10            8
# 10110         4
# 10100         4
# 110100        3
# 1             3
# 100010        2
# 110110        2
# 11000         2
# 111100        1
# 1000          1
# 111000        1
# 11110         1
# 110011        1
# 11100         1
# Name: FRSHTT, dtype: int64

# %%
# Key for columns 'FRSHTT'
# 'FRSHTT': Indicators (1 = yes, 0 = no/not reported) for the occurrence during the day of:
# '000000': Sunny / Clear
# '100000': Fog
# '010000': Rain or Drizzle
# '001000': Snow or Ice Pellets
# '000100': Hail
# '000010': Thunder
# '000001': Tornado or Funnel Cloud

# %%
# Drop unused features for by-month analysis
df_lax = df_lax.drop(['SLP', 'STP', 'MXSPD', 'GUST', 'year', 'd', 'MAX', 'MIN'], axis=1).copy()

# %%
df_lax.head(3)
# Out:
#     YEARMODA  TEMP  DEWP  VISIB  WDSP  PRCP  FRSHTT  month
# 0 1973-01-01  58.6  12.9   25.9   8.7   0.0       0      1
# 1 1973-01-02  54.7  27.3   19.1   5.6   0.0       0      1
# 2 1973-01-03  53.3  42.4   22.1   7.1   0.0   10000      1

# %%
# Return subset query of sunny/clear days, foggy days, rainy days, and foggy+rainy days
df_lax_sfr = df_lax.query('FRSHTT == 0 | FRSHTT == 100000 | FRSHTT == 10000 | FRSHTT == 110000').copy()

# %%
# Transcribe weather event codes to str text
event_code = {0: "clear", 100000: "fog", 10000: "rain", 110000: "fog+rain"}
df_lax_sfr['FRSHTT'] = df_lax_sfr['FRSHTT'].map(event_code)

# %%
df_lax_sfr.set_index('YEARMODA', inplace=True)

# %%
# N-sizes by weather event for each daily observation 
df_lax_sfr['FRSHTT'].value_counts()
# Out:
# clear       10009
# fog          4251
# rain         1169
# fog+rain      958
# Name: FRSHTT, dtype: int64

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))
df_lax_sfr['VISIB'].hist(bins=100);

# %%
# Looks like around 1997-1998 the convention for measuring visibility was changed..
plt.figure(figsize=(8,6))
df_lax_sfr['VISIB'].plot();

# %%
# The international definition of fog is a visibility of less than 1 kilometre (3,300 ft); 
# mist is a visibility of between 1 kilometre (0.62 mi) and 2 kilometres (1.2 mi) and haze 
# from 2 kilometres (1.2 mi) to 5 kilometres (3.1 mi). (wikipedia.org)

# According to Wikipedia.org, fog forms when the differnce between temperature and 
# dew point is less than 2.5 degrees Celsius.

# %%
# Feature Engineering:
# Adjust visibility values: impose max of 10 miles. Also, new feature of 'fog' based on
# Visibility of less than 1.2 miles
def adjust_visibility_values(col):
    if col > 10:
        return 10
    else:
        return col

    
def fog_based_visibility(col):
    if col < 1.2:
        return 1
    else:
        return 0

    
df_lax_sfr['VISIB'] = df_lax_sfr['VISIB'].apply(adjust_visibility_values)
df_lax_sfr['FOG_VISIB'] = df_lax_sfr['VISIB'].apply(fog_based_visibility)

# %%
plt.figure(figsize=(8,6))
df_lax_sfr['VISIB'].plot();

# %%
df_lax_sfr['FOG_VISIB'].plot()

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(12,8))
sns.heatmap(df_lax_sfr.corr(), cmap='coolwarm')

# %%
sns.pairplot(df_lax_sfr);

# %%
# Explore data: groupby month means
groupby_month_df_lax_sfr = df_lax_sfr.groupby('month').mean()

# %%
groupby_month_df_lax_sfr
# Out:
#             TEMP       DEWP     VISIB      WDSP      PRCP  FOG_VISIB
# month
# 1      57.031841  42.636105  8.599076  5.539161  0.096752   0.003554
# 2      57.405016  45.181975  8.682837  6.423119  0.117038   0.005486
# 3      58.260014  47.854971  8.746398  6.961527  0.072954   0.002882
# 4      60.156576  49.478766  8.967597  7.495738  0.041220   0.000000
# 5      62.434253  53.660085  8.388040  7.248266  0.031769   0.000000
# 6      65.322808  57.176820  8.070728  6.977489  0.003128   0.000000
# 7      68.321186  60.522270  8.096385  6.974403  0.001793   0.000000
# 8      69.077673  61.133237  8.034465  6.805925  0.004220   0.000000
# 9      68.733559  59.947372  8.072523  6.423649  0.007523   0.000751
# 10     65.923043  54.966739  7.906739  6.011304  0.014928   0.005797
# 11     61.425710  46.395590  8.445291  5.612780  0.029380   0.003737
# 12     57.145178  41.546701  8.404206  5.487382  0.064133   0.011603

# %%
# Export cleaned dataset to csv for future use
df_lax_sfr.to_csv(dir_data + file_noaa_clean, columns=df_lax_sfr.columns)

# %%
df_lax_sfr
# Out:
#             TEMP  DEWP  VISIB  WDSP  PRCP    FRSHTT  month  FOG_VISIB
# YEARMODA
# 1973-01-01  58.6  12.9   10.0   8.7  0.00     clear      1          0
# 1973-01-02  54.7  27.3   10.0   5.6  0.00     clear      1          0
# 1973-01-03  53.3  42.4   10.0   7.1  0.00      rain      1          0
# 1973-01-04  51.5  36.5   10.0   6.2  3.15      rain      1          0
# 1973-01-05  46.4  29.0   10.0   4.5  0.00     clear      1          0
# 1973-01-06  48.7  23.2   10.0   5.2  4.33     clear      1          0
# 1973-01-07  48.5  31.8   10.0   4.8  0.00     clear      1          0
# 1973-01-08  50.4  40.1    8.2   4.7  0.00      rain      1          0
# 1973-01-09  54.0  47.5    6.9   6.7  0.24  fog+rain      1          0
# 1973-01-10  54.0  49.7   10.0   4.5  0.04      rain      1          0
# 1973-01-11  54.6  47.9    9.8   4.9  0.00     clear      1          0
# 1973-01-12  57.0  50.8    5.3   4.9  0.00     clear      1          0
# 1973-01-13  60.3  51.4    8.5   4.6  0.00       fog      1          0
# 1973-01-14  64.1  46.5   10.0   5.3  0.00     clear      1          0
# 1973-01-15  58.9  53.1    3.6   4.7  3.15       fog      1          0
# 1973-01-16  56.7  51.4    8.4   5.8  0.00  fog+rain      1          0
# 1973-01-17  56.7  51.0   10.0   9.0  1.65  fog+rain      1          0
# 1973-01-18  54.5  47.8   10.0   7.9  0.87      rain      1          0
# 1973-01-19  54.4  43.2   10.0   9.6  0.51  fog+rain      1          0
# 1973-01-20  51.6  27.2   10.0  11.7  0.00     clear      1          0
# 1973-01-21  50.2  37.9   10.0   5.8  0.00     clear      1          0
# 1973-01-22  52.2  36.4   10.0   5.8  0.00     clear      1          0
# 1973-01-23  53.2  26.7   10.0   5.3  0.00     clear      1          0
# 1973-01-24  53.7  34.0   10.0   4.5  5.91     clear      1          0
# 1973-01-25  52.6  43.5   10.0   5.4  0.00     clear      1          0
# 1973-01-26  53.5  39.0   10.0  11.2  0.00      rain      1          0
# 1973-01-27  53.0  35.2   10.0   6.0  0.00     clear      1          0
# 1973-01-28  58.9  27.3   10.0   7.2  0.00     clear      1          0
# 1973-01-29  58.6  31.4   10.0   5.0  3.54     clear      1          0
# 1973-01-30  54.5  48.6   10.0   6.6  0.00  fog+rain      1          0
# ...          ...   ...    ...   ...   ...       ...    ...        ...
# 2018-05-03  59.9  49.0    9.4   6.0  0.00     clear      5          0
# 2018-05-04  64.5  53.3    9.5   7.1  0.00     clear      5          0
# 2018-05-05  65.2  54.7    9.9   7.1  0.00     clear      5          0
# 2018-05-06  63.2  53.5    9.9   7.2  0.00     clear      5          0
# 2018-05-07  61.9  53.6    8.7   6.7  0.00     clear      5          0
# 2018-05-08  61.7  55.6    6.4   5.7  0.00       fog      5          0
# 2018-05-09  63.1  55.6    8.3   6.3  0.00     clear      5          0
# 2018-05-10  63.4  55.9    9.0   5.4  0.00     clear      5          0
# 2018-05-11  62.5  54.2    9.2   8.1  0.00     clear      5          0
# 2018-05-12  61.3  53.1    9.4   6.0  0.00      rain      5          0
# 2018-05-13  61.9  51.4    9.6   7.2  0.00      rain      5          0
# 2018-05-14  61.7  52.2    9.3   9.0  0.05     clear      5          0
# 2018-05-15  61.8  52.3    9.3   8.8  0.00     clear      5          0
# 2018-05-16  62.1  51.8    9.5   9.8  0.00       fog      5          0
# 2018-05-17  62.6  52.1    9.4   9.3  0.00     clear      5          0
# 2018-05-18  61.9  53.6    9.3   6.2  0.00     clear      5          0
# 2018-05-19  61.7  54.2    9.9   6.3  0.00     clear      5          0
# 2018-05-20  62.4  54.6   10.0   7.6  0.00     clear      5          0
# 2018-05-21  61.5  52.7    9.1   7.2  0.00     clear      5          0
# 2018-05-22  62.0  51.7    9.3   6.2  0.00     clear      5          0
# 2018-05-23  61.6  53.7    9.3   8.4  0.00     clear      5          0
# 2018-05-24  61.2  54.0    9.3   6.8  0.00      rain      5          0
# 2018-05-25  62.2  52.2    9.7  10.5  0.00     clear      5          0
# 2018-05-26  62.3  52.0   10.0  11.1  0.00     clear      5          0
# 2018-05-27  63.0  52.6   10.0   6.8  0.00     clear      5          0
# 2018-05-28  62.9  55.2    9.0   6.8  0.00     clear      5          0
# 2018-05-29  63.1  56.4    7.5   6.7  0.00     clear      5          0
# 2018-05-30  62.5  56.0    8.9   6.8  0.00      rain      5          0
# 2018-05-31  64.6  55.4    9.2   8.1  0.00     clear      5          0
# 2018-06-01  63.4  53.7    9.4   6.6  0.00     clear      6          0
#
# [16387 rows x 8 columns]
